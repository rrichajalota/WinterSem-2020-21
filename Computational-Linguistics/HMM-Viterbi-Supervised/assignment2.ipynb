# %% [markdown]
# First, implement the Viterbi algorithm for finding the
# optimal state (tag) sequence given the sequence of observations (words). We
# suggest you test your implementation on a small example for which you
# know the correct tag sequence, such as the Eisner’s Ice Cream HMM from
# the lecture. Make sure your Viterbi algorithm runs properly on the example
# before you proceed to the next step.

# %% [markdown]
# ## Viterbi Algorithm

# %%
import numpy as np

# %%
states = ['h', 'c'] # states 
states2ind = {'h': 0, 'c': 1}
obs = [3,1,3] # observations
obs2ind = {'1': 0, '2': 1, '3': 2}
Im = np.array([0.8, 0.2]) # follows the order of states as in Q
Tm = np.array([[0.7, 0.3],[0.4, 0.6]])
Em = np.array([[0.2, 0.4, 0.4], [0.5, 0.4, 0.1]])

# %%
str(obs[0])
# Out:
# '3'

# %%
# perform sanity check to confirm if all the probabilities corresponding to a state sum to 1 

def perform_sanity_check(Im, Tm, Em):
    assert(np.sum(Im) == 1)
    assert(all(np.sum(Tm, axis=1)) == 1)
    assert(all(np.sum(Em, axis=1)) == 1)
    
perform_sanity_check(Im, Tm, Em)

# %%
# viterbi algo for POS tagging i.e. tagger implementation 
def viterbi(states, obs, Im, Tm, Em, obs2ind):
    
    Vp = np.zeros((len(states), len(obs))) # matrix of max probabilities of dim. KxT where T = number of obs/transitions and K = number of states
    Vs = np.zeros((len(states), len(obs)))# matrix that contains prev state corresponding to the max prob. of states stored in Vp; KxT dim
    
    
    # initial run
    for s in range(len(states)):
        if str(obs[0]) not in obs2ind: # if we encounter an unknown word, 
            E_s_w = 1
        else:
            E_s_w = Em[s][obs2ind[str(obs[0])]]
        
        Vp[s, 0] = np.multiply(Im[s], E_s_w)
        Vs[s, 0] = -1 # -1 invalid state to mark that prev. state doesn't exist
    
    # transtion from t = 1,...,T
    for t, y_obs in enumerate(obs):
        
        if t == 0:
            continue
            
        # check if y_obs exists in the vocabulary
        if str(y_obs) not in obs2ind: # if we encounter an unknown word, 
            y_obs_ind = -1  
        else:
            y_obs_ind = obs2ind[str(y_obs)]
        
        for s in range(len(states)):
            #print(Vp[:, t-1], Tm[:,s], Em[s][y_obs-1])
            
            # apply smoothing -> crude approach 
            if y_obs_ind == -1:
                Em_s_w = 1
            else:
                Em_s_w = Em[s][y_obs_ind]
                
            Vp[s, t] = max(np.multiply(np.multiply(Vp[:, t-1], Tm[:,s]), Em_s_w))
            Vs[s,t] = np.argmax(np.multiply(np.multiply(Vp[:, t-1], Tm[:,s]), Em_s_w))
   
    #print(Vp, Vs)     
    
    Z = np.ones((len(obs))).astype(int) # converted to int, because Zi would be used as an index
    X = ['']*len(obs) # list of hidden states 
    Z[-1] = np.argmax(Vp[:,len(obs)-1]) # index of the state that gives the max probability of observing 'o' at t=T
    X[-1] = states[Z[-1]]    # the corresponding hidden state at t=T 
    
    # loop from right to left and fill in the prev states that are marked by the back_pointers at state, t. 
    for t in range(len(Z)-1, 0, -1):
        Z[t-1] = Vs[Z[t]][t]
        X[t-1] = states[Z[t-1]]
        
    return(X)
    
    
    

#print(viterbi(states, obs, Im, Tm, Em, obs2ind))

# %% [markdown]
# ### Training.
# Second, learn the parameters of your HMM from data, i.e. the
# initial, transition, and emission probabilities. Implement a maximum like-
# lihood training procedure for supervised learning of HMMs.

# %%
# first load and read the corpus - fetch unique words, POS-tags, all_words, all_tags 
# ek emission prob matrix, transition prob matrix, initial prob
# viterbi 
# some preprocessing?
type(reader_corpus)
# Out:
# nltk.corpus.reader.conll.ConllCorpusReader

# %%
from nltk.corpus.reader import ConllCorpusReader, TaggedCorpusReader

def read_corpus(path='de-utb/de-train.tt', columntypes=('words', 'pos')): # by default reads the training data
    reader_corpus = ConllCorpusReader('.', path, columntypes=columntypes)
    print(len(reader_corpus.tagged_words()))
    return reader_corpus
    
reader_corpus = read_corpus()
# Out:
# 264906

# %%
def obj_dict_index(list_obj):
    return dict(zip(list_obj, range(0,len(list_obj))))

def record_states_from_corpus(reader_corpus_obj):
    states = list(set([tup[1] for tup in reader_corpus.tagged_words()])) # list of unique POS tags
    #states.sort()
    state_index = obj_dict_index(states)
    return states, state_index

def record_obs_from_corpus(reader_corpus_obj):
    obs = list(set([tup[0] for tup in reader_corpus.tagged_words()])) # list of unique observations
    #obs.sort()
    obs_index = obj_dict_index(obs)
    return obs, obs_index

# %%
states, state_index = record_states_from_corpus(reader_corpus)
obs, obs_index = record_obs_from_corpus(reader_corpus)

# %%
#states = list(([tup[1] for tup in reader_corpus.tagged_words()])) # list of all POS tags
#states.sort() # the following order will be followed in all the matrices
#state_index = dict(zip(states, range(0,len(states)))) # states_2_index
state_index
# Out:
# {'.': 2,
#  'ADJ': 0,
#  'ADP': 7,
#  'ADV': 10,
#  'CONJ': 11,
#  'DET': 8,
#  'NOUN': 1,
#  'NUM': 5,
#  'PRON': 3,
#  'PRT': 4,
#  'VERB': 6,
#  'X': 9}

# %%
#obs = list(set([tup[0] for tup in reader_corpus.tagged_words()])) # list of unique observations
#obs.sort()
#obs_index = dict(zip(obs, range(0,len(obs)))) # obs_word_2_index
obs_index['Der']
# Out:
# 21693

# %%
Im = np.zeros(len(states)) #  initial probab matrix for all states - len K
Em = np.zeros((len(states), len(obs))) # dim KxN
Tm = np.zeros((len(states), len(states))) # dim KxK

# %%
for sent in reader_corpus.tagged_sents():
    prev_state_index = -1
    for i, tup in enumerate(sent):
        #print(tup[1], tup[0])
        hidden_state_index = state_index[tup[1]]
        obs_col = obs_index[tup[0]]
        #print(state_index[tup[1]])
        
        if i == 0: # first word of the sentence 
            Im[hidden_state_index] += 1
        else:
            Tm[prev_state_index][hidden_state_index] += 1
        
        Em[hidden_state_index][obs_col] += 1
        prev_state_index = hidden_state_index

# divide the count by the corresponding totals to get probability         
Im /= len(reader_corpus.tagged_sents()) 
Tm /= np.sum(Tm, axis=1).reshape(-1,1)
Em /= np.sum(Em, axis=1).reshape(-1,1)

# %%
perform_sanity_check(Im, Tm, Em)

# %% [markdown]
# The test set (de-test.t) is a copy of the evaluation set with tags stripped, as you should
# tag the test set using your tagger and then compare your results with the
# gold-standard ones in the evaluation set. The corpus uses the 12-tag univer-
# sal POS tagset by Petrov et al. (2012)

# %%
#test_corpus = TaggedCorpusReader('.', r'de-utb/de-test.t')

#test_obs = record_obs_from_corpus(test_corpus)
#for sent in test_corpus.tagged_sents():
#    print(sent)
#    break

# %%
eval_corpus = ConllCorpusReader('.', 'de-utb/de-eval.tt', columntypes=('words', 'pos'))
predicted_tags = []

for sent in eval_corpus.tagged_sents():
    words = [tup[0] for tup in sent]
    predicted_tags.append(viterbi(states, words, Im, Tm, Em, obs_index))

# %%
predicted_tags
# Out:
# [['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'NUM',
#   'VERB',
#   '.',
#   'VERB',
#   'CONJ',
#   'CONJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['VERB', 'ADV', 'ADV', 'DET', 'NOUN', '.'],
#  ['.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', '.', '.'],
#  ['.', 'NOUN', 'NOUN', 'VERB', 'PRON', 'ADV', 'NUM', 'VERB', '.', '.'],
#  ['.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   '.'],
#  ['.', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADV', 'VERB', '.', '.'],
#  ['NUM', 'NOUN', 'ADJ', 'ADV', 'VERB', 'VERB', 'VERB', '.'],
#  ['DET', 'NOUN', 'VERB', 'PRON', 'VERB', '.'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'PRON',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN'],
#  ['ADV', 'ADJ', 'VERB', 'ADV', 'DET', 'NOUN', '.'],
#  ['PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['PRON', 'ADP', 'NOUN', 'DET', 'ADJ', 'NOUN', '.'],
#  ['ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['ADP',
#   'PRON',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.'],
#  ['ADV', 'PRON', 'ADV', '.', 'CONJ', 'ADV', '.'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   '.',
#   'ADV',
#   'PRT',
#   'ADV',
#   'ADV',
#   '.'],
#  ['ADV',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'PRON',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   'ADV',
#   '.'],
#  ['ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'PRON', 'PRT', 'ADV', 'PRT', '.'],
#  ['ADV', 'VERB', 'PRON', 'PRON', 'PRT', 'VERB', '.'],
#  ['ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADV', 'VERB', 'PRON', 'ADV', '.'],
#  ['ADV',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', '.'],
#  ['ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   '.',
#   'ADV',
#   'PRON',
#   'VERB',
#   'PRT',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PRT',
#   '.',
#   'ADV',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['ADV',
#   'CONJ',
#   'PRON',
#   'PRT',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'CONJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   '.'],
#  ['ADV',
#   'PRT',
#   '.',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADP', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', '.'],
#  ['ADP',
#   'PRON',
#   'VERB',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.'],
#  ['NOUN', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'NOUN', 'VERB', '.'],
#  ['NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'VERB', '.'],
#  ['ADV',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'PRT',
#   '.'],
#  ['ADP', 'NOUN', 'VERB', 'PRON', 'ADP', 'NOUN', 'ADV', 'VERB', '.', '.', '.'],
#  ['ADP', 'NOUN', 'NOUN', 'VERB', 'PRON', 'ADP', 'NUM', 'NOUN', '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['NOUN', 'NOUN', 'ADP', 'NOUN', 'ADV', '.'],
#  ['ADP', 'DET', 'NOUN', '.'],
#  ['NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'ADV',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['VERB', '.', 'NOUN', 'ADP', 'DET', 'NOUN', '.'],
#  ['VERB', 'ADV', 'ADV', 'ADV', 'ADP', 'NOUN', '.'],
#  ['VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADP',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'VERB',
#   '.',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['VERB', 'ADV', 'ADJ', 'ADP', 'DET', 'NOUN', '.'],
#  ['VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'PRON',
#   '.'],
#  ['ADP', 'ADP', 'NUM', 'PRT', '.'],
#  ['NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['CONJ', 'PRON', 'DET', 'ADJ', 'NOUN', 'VERB', 'CONJ', 'PRON', 'VERB', '.'],
#  ['ADV', 'VERB', 'DET', 'NOUN', 'ADV', 'ADV', 'VERB', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PRT',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   '.'],
#  ['ADP', 'PRON', 'VERB', 'PRON', 'DET', 'ADJ', 'VERB', '.'],
#  ['NOUN', 'NOUN', '.', 'X'],
#  ['ADV', 'VERB', 'PRON', 'ADV', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'PRON',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'ADV', 'VERB', 'VERB', '.'],
#  ['DET', 'NOUN', 'VERB', 'ADV', 'PRON', 'VERB', '.'],
#  ['DET',
#   'ADJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'ADP', 'ADV', 'NUM', 'NOUN', 'ADV', 'PRT', 'VERB', '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'CONJ',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'ADV',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'PRON', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'ADV', 'PRT', 'ADP', 'DET', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'VERB', 'ADV', 'NUM', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP', 'PRON', 'ADV', 'ADP', 'NOUN', 'PRT', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV', 'ADV', 'PRT', 'ADV', 'ADJ', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADJ',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   '.',
#   'PRON',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET'],
#  ['DET', 'NOUN', 'VERB', 'PRON', '.'],
#  ['DET', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADJ', '.', '.', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADP',
#   'PRON',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'ADV', 'ADJ', 'NOUN', 'VERB', 'ADV', 'ADJ', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRT',
#   '.',
#   'ADJ',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'ADV', 'VERB', 'ADV', 'ADV', 'ADJ', '.'],
#  ['DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADV', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   '.',
#   'DET',
#   'NOUN',
#   'ADV',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   '.',
#   'CONJ',
#   'PRT',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'PRT',
#   'ADV',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'VERB', 'PRON', 'ADV', 'VERB', 'ADV', 'PRT', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'VERB',
#   '.',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.',
#   'CONJ',
#   'VERB',
#   'VERB',
#   'PRON',
#   'PRON',
#   'PRT',
#   '.'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', '.'],
#  ['PRON', 'VERB', 'NOUN', '.'],
#  ['PRON', 'NOUN', 'VERB', 'PRON', 'ADP', 'NUM', 'PRT', 'ADV', '.'],
#  ['PRON', 'NOUN', 'VERB', 'PRON', 'ADV', 'ADV', 'PRT', 'VERB', '.'],
#  ['PRON', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADJ', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'DET',
#   'PRON',
#   'ADJ',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADJ', '.'],
#  ['ADV', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADV', 'VERB', 'PRON', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'PRT',
#   '.',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADJ',
#   'ADJ',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.'],
#  ['DET', 'ADJ', 'NOUN', '.'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['DET', 'ADJ', 'ADJ', 'NOUN', '.'],
#  ['DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['DET', 'NOUN', 'VERB', '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADV',
#   'PRT',
#   'ADV',
#   '.'],
#  ['NOUN',
#   'ADJ',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN', 'CONJ', 'DET', 'NOUN', '.', '.', '.', '.', '.', '.'],
#  ['PRON',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'X',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADV',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   'PRON',
#   'PRON',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'PRT', 'PRT', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'PRT',
#   '.',
#   'ADP',
#   'PRON',
#   'PRON',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADP', 'PRON', 'PRT', 'DET', 'ADJ', 'NOUN', '.'],
#  ['PRON', 'VERB', 'ADV', 'PRON', 'NOUN', 'CONJ', 'ADJ', 'VERB', 'NOUN', '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRT',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'PRON',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'PRON', 'ADV', 'PRON', 'VERB', '.'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'NUM',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'PRON',
#   'ADV',
#   'ADV',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'NOUN',
#   'PRT',
#   'CONJ',
#   'PRT',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['X',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   '.',
#   'PRON',
#   'DET',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADJ',
#   'CONJ',
#   'ADJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'PRON',
#   '.',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'ADJ',
#   'ADV',
#   'PRT',
#   'ADV',
#   'VERB',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN', 'VERB', 'PRON', 'ADV', 'ADP', 'DET', 'NOUN', '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'DET',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'PRON',
#   'NOUN',
#   '.',
#   'ADV',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'VERB',
#   '.'],
#  ['ADP', 'PRON', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRON', 'NOUN', '.'],
#  ['PRON', 'ADV', 'ADP', 'ADP', 'NOUN', '.'],
#  ['DET', 'ADJ', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', '.'],
#  ['PRON',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   '.'],
#  ['PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'PRON',
#   'PRT',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'ADV',
#   'PRON',
#   'PRT',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['NOUN', 'VERB', 'ADV', 'DET', 'ADJ', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.'],
#  ['DET', 'ADJ', 'NOUN', '.', 'NOUN', '.', 'ADV', 'VERB', '.'],
#  ['ADP', 'PRON', 'ADV', 'ADJ', 'CONJ', 'NOUN'],
#  ['NOUN', 'CONJ', 'DET', 'NOUN', 'VERB', 'NUM', 'NOUN', '.', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'CONJ',
#   'ADJ',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'NOUN'],
#  ['ADJ', 'NOUN', 'CONJ', 'DET', 'NOUN', '.'],
#  ['ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.'],
#  ['ADJ', 'NOUN', '.', 'NOUN', '.'],
#  ['VERB',
#   'ADV',
#   'ADV',
#   'DET',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['X',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'CONJ',
#   'PRT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['X', 'PRT', '.'],
#  ['X',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['VERB',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'PRT',
#   '.',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV', '.', 'ADP', 'NUM', 'NOUN', 'VERB', 'PRON', '.'],
#  ['ADV', 'ADJ', 'NOUN', 'VERB', 'PRON', 'ADJ', 'NOUN', '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   'ADV',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'DET', 'NOUN', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   '.',
#   'VERB',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'PRON', 'VERB', 'PRT', 'ADV', 'VERB', '.'],
#  ['PRON', 'VERB', 'PRON', 'VERB', 'PRON', 'ADV', 'VERB', '.'],
#  ['PRON', 'VERB', 'NOUN', 'VERB', 'ADV', 'ADV', 'VERB', '.'],
#  ['PRON', 'VERB', 'PRON', 'ADV', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON', 'NOUN', 'CONJ', 'ADV', 'DET', 'NOUN', 'PRT', '.'],
#  ['PRON', 'VERB', 'ADV', 'ADV', 'ADV', 'ADV', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADJ',
#   '.',
#   'CONJ',
#   'PRON',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   'CONJ',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'ADV',
#   'PRT',
#   '.',
#   'ADJ',
#   'VERB',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   'VERB',
#   'ADV',
#   'ADV',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'ADV',
#   'PRON',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB'],
#  ['ADP', 'NOUN', 'VERB', 'PRON', 'ADV', 'VERB', '.'],
#  ['ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'PRON',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['VERB',
#   'ADV',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PRT',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PRON',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'ADV', 'ADJ', '.'],
#  ['PRON', 'VERB', 'PRON', 'ADV', 'DET', 'ADJ', 'NOUN', 'VERB', '.'],
#  ['PRON', 'ADV', 'PRT', '.', '.', '.', '.', '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'PRT', 'VERB', '.'],
#  ['VERB', 'PRON', 'ADV', 'VERB', '.'],
#  ['PRON', 'VERB', '.', 'PRON', 'VERB', 'ADV', 'VERB', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.'],
#  ['ADV',
#   '.',
#   'ADV',
#   'ADV',
#   'ADV',
#   '.',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   '.',
#   'PRON',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['NOUN', 'CONJ', 'ADV', 'VERB', 'PRON', 'ADJ', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN'],
#  ['ADV', 'PRT', 'ADV', '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'X'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.'],
#  ['PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'PRT', 'ADV', 'VERB', '.'],
#  ['PRON', 'VERB', 'ADV', 'DET', 'NOUN', 'NOUN', '.'],
#  ['PRON',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'PRT',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['PRON', 'NOUN', '.', 'ADV', 'ADV', 'PRON', 'NOUN', '.'],
#  ['PRON',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'PRT',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.'],
#  ['ADP', 'NUM', 'NOUN', 'VERB', 'PRON', 'ADV', 'ADV', 'PRT', '.'],
#  ['ADJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADJ',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN', 'CONJ', 'ADV', 'PRT', 'ADV', 'ADJ', 'NOUN', '.'],
#  ['PRON', 'ADV', 'VERB', '.'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'PRT',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN', 'ADV', 'ADP', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['ADJ',
#   '.',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'PRON',
#   'ADJ',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'CONJ', 'DET', 'ADJ', 'NOUN', '.'],
#  ['NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADJ',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN', 'PRON', 'ADP', 'DET', 'NOUN', '.'],
#  ['NOUN',
#   'PRT',
#   'ADV',
#   'ADJ',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'PRT',
#   'ADV',
#   'ADJ',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'PRT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   '.'],
#  ['ADJ', 'CONJ', 'PRON', 'NOUN', 'PRT', 'VERB', 'VERB', '.'],
#  ['ADV', 'ADV', 'VERB', 'PRON', 'DET', 'NOUN', 'ADP', '.', 'NOUN', '.', '.'],
#  ['ADV', 'CONJ', 'ADJ', '.'],
#  ['ADJ', 'NOUN', '.', 'NOUN', '.'],
#  ['DET', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['ADV', 'ADJ', 'NOUN', '.'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV', 'PRT', 'VERB', '.', 'PRON', 'VERB', 'ADV', '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'PRT',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   '.',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'DET',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   '.'],
#  ['ADV', 'VERB', 'PRON', 'VERB', '.'],
#  ['NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN', '.', 'PRON', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.'],
#  ['ADJ', '.', 'NOUN', '.', '.', 'NOUN', 'ADV', 'ADP', 'NOUN', 'VERB', '.'],
#  ['NOUN', 'CONJ', 'DET', 'NOUN', 'VERB', 'ADV', 'ADJ', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADV',
#   'NOUN',
#   '.',
#   '.'],
#  ['CONJ', 'DET', 'NOUN', 'VERB', 'NUM', 'NOUN', '.', 'X', '.'],
#  ['CONJ',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.'],
#  ['NOUN',
#   '.',
#   'ADJ',
#   '.',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'ADV',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   '.'],
#  ['PRON',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NUM',
#   '.'],
#  ['PRON',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'CONJ',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADV',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'DET', 'ADJ', 'NOUN', '.'],
#  ['PRON', 'VERB', '.'],
#  ['ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'NOUN', '.'],
#  ['ADP', 'PRON', 'ADV', 'PRON', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['VERB',
#   'ADV',
#   'PRT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADV', 'PRON', 'ADV', 'ADV', 'VERB', 'VERB', 'PRON', 'DET', 'NOUN', '.'],
#  ['NOUN', 'PRON', 'PRON', 'VERB', '.'],
#  ['CONJ',
#   'PRON',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   '.'],
#  ['PRON',
#   'PRT',
#   'ADJ',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'VERB',
#   '.'],
#  ['ADV', 'ADV', 'ADP', 'ADJ', 'NOUN', '.'],
#  ['PRON', 'VERB', 'ADP', 'PRON', 'NOUN', 'PRT', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PRT',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['PRON', 'VERB', 'PRON', 'VERB', '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADV', 'PRT', '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'PRON', 'VERB', 'ADV', 'VERB', '.'],
#  ['ADV', 'ADV', 'ADJ', 'NOUN', 'DET', 'NOUN', 'VERB', '.'],
#  ['NOUN',
#   'VERB',
#   'ADV',
#   'VERB',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADJ',
#   'ADP',
#   'NOUN'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   'PRT',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADP',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'VERB', '.'],
#  ['ADV', 'VERB', 'PRON', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.'],
#  ['PRON', 'ADV', 'VERB', '.'],
#  ['.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'CONJ',
#   'VERB',
#   'ADJ',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'VERB',
#   '.',
#   '.',
#   'VERB',
#   'PRON',
#   '.',
#   '.'],
#  ['.',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'NUM',
#   '.'],
#  ['.',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['.',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.',
#   '.'],
#  ['.', 'NOUN', 'VERB', 'CONJ', 'PRON', '.', '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   '.'],
#  ['.', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'ADP', 'NUM', 'NOUN', '.', '.', '.'],
#  ['.', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADV', 'PRT', '.', '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'ADV',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   '.'],
#  ['.',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   '.'],
#  ['.',
#   'ADP',
#   'NOUN',
#   'DET',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   '.'],
#  ['.',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   '.'],
#  ['.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   '.'],
#  ['.', 'NOUN', 'NOUN', 'VERB', 'PRT', '.'],
#  ['.',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.',
#   '.'],
#  ['.',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'VERB',
#   'PRON',
#   '.',
#   '.'],
#  ['.',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['.',
#   'ADV',
#   'VERB',
#   '.',
#   'PRON',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NUM',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NUM',
#   '.',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NUM',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NUM', 'NOUN', 'VERB', 'NUM', 'NOUN', '.'],
#  ['NUM',
#   '.',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'NUM',
#   'ADV',
#   '.'],
#  ['NUM',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   '.'],
#  ['CONJ', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRT', '.', '.'],
#  ['PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADJ',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   '.',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADV',
#   '.',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN', 'VERB', 'ADV', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', '.'],
#  ['NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NUM',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   '.',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'PRT',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PRT',
#   'ADV',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['ADP', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADV', 'VERB'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   '.',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'ADP',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   '.',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
# ...
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON', 'NOUN', 'ADP', 'NOUN', '.'],
#  ['.',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['.', 'NOUN', 'PRON', 'DET', 'NOUN', '.', '.'],
#  ['ADV',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRT',
#   'ADP',
#   '.',
#   'ADJ',
#   '.',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PRT',
#   'CONJ',
#   'NOUN',
#   'PRT',
#   'ADJ',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   '.'],
#  ['NOUN', 'VERB', 'DET', 'NOUN', '.', 'NOUN', 'ADP', 'PRON', 'VERB', '.'],
#  ['NOUN', '.'],
#  ['ADV', 'PRT', '.'],
#  ['NOUN',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRT',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   '.'],
#  ['DET', 'NOUN', 'VERB', '.', '.', 'NOUN', 'VERB', 'ADJ', '.'],
#  ['.',
#   'PRON',
#   'VERB',
#   'PRT',
#   '.',
#   '.',
#   'VERB',
#   'PRON',
#   'ADV',
#   'ADV',
#   'ADV',
#   'PRT',
#   'ADV',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET', 'NOUN', 'VERB', '.', 'NOUN', 'ADP', 'DET', 'NOUN', '.'],
#  ['ADJ',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'CONJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'PRT',
#   '.',
#   '.',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   'ADP',
#   'NOUN',
#   '.',
#   '.'],
#  ['ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'NOUN',
#   'CONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADV',
#   '.',
#   'ADV',
#   'ADV',
#   'ADP',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADP',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'PRT',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADP',
#   'NUM',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['PRON',
#   'PRON',
#   'PRT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'PRON',
#   'VERB',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADV',
#   'ADV',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'PRON',
#   'VERB',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN'],
#  ['PRON',
#   'VERB',
#   'NUM',
#   'NOUN',
#   '.',
#   '.',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.',
#   '.'],
#  ['ADP', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'DET', 'NOUN', '.'],
#  ['NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.'],
#  ['DET', 'NOUN', '.', 'NOUN', 'VERB', 'DET', 'NOUN', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'PRON',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'NUM',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADV',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   '.',
#   'NOUN',
#   '.',
#   'VERB',
#   'VERB',
#   '.'],
#  ['DET'],
#  ['DET'],
#  ['NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADV',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'VERB',
#   '.',
#   'VERB',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['NOUN', '.', 'NOUN'],
#  ['DET', 'ADV', 'VERB', 'ADV', 'PRT', 'CONJ', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.'],
#  ['NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.'],
#  ['ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'NOUN',
#   'DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRT',
#   '.'],
#  ['DET'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'ADJ',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NUM',
#   'VERB',
#   '.',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'DET',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   'PRT',
#   'VERB',
#   '.'],
#  ['.', 'CONJ', 'ADP', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', '.', '.'],
#  ['PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'ADP',
#   'ADV',
#   'VERB',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRT',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PRT',
#   '.',
#   'CONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'ADV',
#   '.'],
#  ['PRON',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'PRT',
#   'VERB',
#   '.'],
#  ['.', 'PRON', 'NOUN', 'VERB', 'PRT', '.'],
#  ['DET',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'CONJ',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'PRT',
#   '.'],
#  ['NOUN',
#   '.',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADP',
#   'CONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   '.',
#   '.',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'DET',
#   'ADJ',
#   'ADJ',
#   'CONJ',
#   'ADV',
#   'PRT',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV', 'VERB', 'PRON', 'ADV', 'PRT', '.'],
#  ['ADP',
#   'PRON',
#   'PRT',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['PRON',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   '.',
#   'NUM',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   '.'],
#  ['.', 'DET', 'NOUN', 'VERB', 'ADJ', '.', '.'],
#  ['ADJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   '.',
#   'ADV',
#   'ADP',
#   'PRON',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADV',
#   'PRON',
#   'ADP',
#   'PRON',
#   'VERB',
#   'PRON',
#   'ADV',
#   '.',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['CONJ',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NUM',
#   'VERB',
#   'ADV',
#   'PRT',
#   'VERB',
#   '.'],
#  ['CONJ', 'ADP', 'PRON', 'VERB', 'PRON', 'ADV', 'ADV', '.'],
#  ['ADV', 'ADV', 'VERB', 'ADV', 'PRT', '.', 'ADV', 'ADV', '.', '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'CONJ',
#   'VERB',
#   '.'],
#  ['NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   '.',
#   'NOUN',
#   '.',
#   'ADP',
#   'NOUN',
#   '.',
#   'VERB',
#   '.',
#   'PRON',
#   'VERB',
#   '.',
#   'PRON',
#   'NOUN',
#   '.',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'ADV',
#   'VERB',
#   '.',
#   '.',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   '.',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['ADP', 'NOUN', 'VERB', '.', 'NOUN', '.'],
#  ['NOUN', 'NOUN', 'NOUN'],
#  ['PRON',
#   'PRON',
#   'VERB',
#   '.',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   '.',
#   'CONJ',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'VERB',
#   'ADV',
#   '.'],
#  ['.', 'NOUN', '.', 'NOUN', '.'],
#  ['PRON',
#   'VERB',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   'CONJ',
#   'ADJ',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.'],
#  ['ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'NUM',
#   'NUM',
#   'ADP',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'PRON',
#   'VERB',
#   'PRON',
#   'VERB',
#   '.',
#   'CONJ',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['ADV',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   'CONJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['CONJ', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'VERB', '.'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'VERB',
#   'ADV',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['PRON', 'VERB', 'ADJ', 'NOUN', 'ADP', 'NOUN'],
#  ['.',
#   'CONJ',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADV',
#   '.',
#   '.',
#   'VERB',
#   'DET',
#   'NOUN',
#   '.'],
#  ['CONJ',
#   'DET',
#   'NOUN',
#   '.',
#   'PRON',
#   'PRON',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'VERB',
#   'VERB',
#   '.',
#   'ADV',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADV',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'VERB',
#   '.',
#   'VERB',
#   'ADJ',
#   '.'],
#  ['NOUN'],
#  ['ADV', 'DET', 'NOUN'],
#  ['PRON', 'VERB', 'ADV', 'ADP', 'NOUN', 'NOUN', '.'],
#  ['DET'],
#  ['ADP', 'NOUN', 'NOUN'],
#  ['DET', 'NOUN'],
#  ['ADV',
#   'VERB',
#   'PRON',
#   'DET',
#   'NOUN',
#   'ADP',
#   '.',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'ADV',
#   '.',
#   '.',
#   'ADV',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.',
#   'PRT',
#   'VERB',
#   '.'],
#  ['DET',
#   'NOUN',
#   '.',
#   'DET',
#   'NOUN',
#   '.',
#   'NOUN',
#   '.',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   '.',
#   'VERB',
#   'ADV',
#   'ADV',
#   'ADV',
#   'DET',
#   'NOUN',
#   '.'],
#  ['DET',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.'],
#  ['NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', '.'],
#  ['NOUN', '.', 'NOUN'],
#  ['NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADV', 'VERB', '.'],
#  ['CONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'NUM',
#   'ADP',
#   'DET',
#   'NOUN',
#   '.'],
#  ['NOUN',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   '.',
#   'PRON',
#   'ADV',
#   'ADV',
#   'PRON',
#   'DET',
#   'ADJ',
#   '.',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   '.',
#   'VERB',
#   'ADV',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   '.']]

# %%
def write_tags_to_file(predicted_tags:list, test_file='./de-utb/de-test.t', tagged_file='de-utb/de-tagged.tt'):
    with open(test_file) as inp_file, open(tagged_file, 'w') as op_file:
        i = 0
        j = 0
        for line in inp_file:
            if line == '\n': # delimiter marks the end of sentence
                i += 1
                j = 0
                op_file.write("\n")
                continue 
            word = line.strip() # remove any whitespace chars
            tag = predicted_tags[i][j]
            j += 1
            op_file.write(word+"\t"+tag+"\n")
            

write_tags_to_file(predicted_tags)

# %%
eval_obs[1]
# Out:
# 'schäumt'

# %%
eval_obs_in[eval_obs[1]]
# Out:
# 1

# %%
Em[:][3]
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
with open('de-utb/de-test.t') as f:
    lines = f.read()
    print(lines)
# Out:
# Der
# Hauptgang
# war
# in
# Ordnung
# ,
# aber
# alles
# andere
# als
# umwerfend
# .
#
# Ich
# habe
# dort
# 2007
# meinen
# OWD
# gemacht
# und
# weil
# mir
# das
# Tauchen
# so
# gefiel
# hab
# ich
# dort
# noch
# im
# selben
# Jahr
# den
# AOWD
# und
# den
# Deep
# drangehängt
# .
#
# Ist
# ja
# wohl
# ein
# Witz
# .
#
# "
# Bitte
# Termin
# im
# Internet
# machen
# .
# "
#
# "
# Welcher
# Kollege
# hat
# Ihnen
# denn
# 99
# gesagt
# ?
# "
#
# (
# Bei
# den
# Damen
# und
# Herren
# des
# besagten
# Mobilfunkanbieters
# bin
# ich
# im
# Gegensatz
# dazu
# bisher
# ausschließlich
# auf
# arrogante
# Unkenntnis
# gestossen
# )
# .
#
# (
# Der
# Shop
# Thomann
# ist
# noch
# sehr
# vielversprechender
# !
# )
#
# 10
# Euro
# günstiger
# selbst
# hätte
# kaufen
# können
# .
#
# 17.45
# Uhr
# hatte
# ich
# bestellt
# .
#
# Aber
# mal
# abwarten
# ,
# was
# sich
# in
# näherer
# Zukunft
# abspielt
# ....
#
# Aber
# über
# die
# Freundlichkeit
# ,
# Zuverlässlichkeit
# und
# Komptenz
# des
# gesamten
# Team
# kann
# man
# nur
# eines
# Sagen
# --
# PEFERKTION
#
# Absolut
# empfehlenswert
# ist
# auch
# der
# Service
# .
#
# Alle
# am
# Wort
# Gottes
# interessierte
# Personen
# sind
# herzlich
# eingelanden
# ,
# Gottesdienst
# mit
# Liedern
# ,
# Gebeten
# und
# Predigten
# mit
# den
# Mitgliedern
# zu
# feiern
# .
#
# Alles
# in
# Allem
# ein
# super
# Erlebnis
# .
#
# Als
# ich
# mit
# meiner
# Frau
# und
# meiner
# Tante
# im
# Oktober
